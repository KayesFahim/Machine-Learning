# %%
#importing libraries 
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt


#feature scalling
from sklearn.pipeline import Pipeline
from sklearn.linear_model import HuberRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import TransformedTargetRegressor
from sklearn.feature_selection import RFE

#Model
from sklearn import svm
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

#Model Selector
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
#load the data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
#Shape of Dataframe
print ("Train data shape:", train.shape)
print ("Test data shape:", test.shape)
# Out:
# Train data shape: (1460, 81)
# Test data shape: (1459, 80)

# %%
# Dataframe visualization
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
# 5   6          50       RL  ...        WD         Normal    143000
# 6   7          20       RL  ...        WD         Normal    307000
# 7   8          60       RL  ...        WD         Normal    200000
# 8   9          50       RM  ...        WD        Abnorml    129900
# 9  10         190       RL  ...        WD         Normal    118000
#
# [10 rows x 81 columns]

# %% [markdown]
# # **Find correlation matrix (in terms of target variable/feature)**

# %%
train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage  ...    MoSold    YrSold  SalePrice
# Id             1.000000    0.011156    -0.010601  ...  0.021172  0.000712  -0.021917
# MSSubClass     0.011156    1.000000    -0.386347  ... -0.013585 -0.021407  -0.084284
# LotFrontage   -0.010601   -0.386347     1.000000  ...  0.011200  0.007450   0.351799
# LotArea       -0.033226   -0.139781     0.426095  ...  0.001205 -0.014261   0.263843
# OverallQual   -0.028365    0.032628     0.251646  ...  0.070815 -0.027347   0.790982
# OverallCond    0.012609   -0.059316    -0.059213  ... -0.003511  0.043950  -0.077856
# YearBuilt     -0.012713    0.027850     0.123349  ...  0.012398 -0.013618   0.522897
# YearRemodAdd  -0.021998    0.040581     0.088866  ...  0.021490  0.035743   0.507101
# MasVnrArea    -0.050298    0.022936     0.193458  ... -0.005965 -0.008201   0.477493
# BsmtFinSF1    -0.005024   -0.069836     0.233633  ... -0.015727  0.014359   0.386420
# ...

# %%
corr_matrix = train.corr()
corr_matrix["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
corr = train.corr()
plt.subplots(figsize=(15,12))
sns.heatmap(corr, vmax=0.9, cmap="Greens", square=True)

# %%
train.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# # **Missing data (Null Value) and Categorical data Handle**

# %%
# Check Null value
train.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#Drop column
train.drop(['Alley'],axis=1,inplace=True)
train.drop(['PoolQC','Fence','MiscFeature'],axis=1,inplace=True)
train.drop(['Id'],axis=1,inplace=True)

# %% [markdown]
# On Alley column has only 94 , PoolQC column has 7, Fence Has 281,  MiscFeature has 54 data only . Here most of the data are missing we will drop those colum. We dont need actually ID column

# %%
# Filling the missing values using mean: 
train['LotFrontage']=train['LotFrontage'].fillna(train['LotFrontage'].mean())

# %% [markdown]
# After Fill up missing value with mean value . Colums contains numerical value

# %%
# Fill missing data with model value. Beacuse this its categorical column
train['BsmtCond']=train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])
train['BsmtQual']=train['BsmtQual'].fillna(train['BsmtQual'].mode()[0])
train['FireplaceQu']=train['FireplaceQu'].fillna(train['FireplaceQu'].mode()[0])
train['GarageType']=train['GarageType'].fillna(train['GarageType'].mode()[0])
train['GarageFinish']=train['GarageFinish'].fillna(train['GarageFinish'].mode()[0])
train['GarageYrBlt']=train['GarageYrBlt'].fillna(train['GarageYrBlt'].mode()[0])
train['GarageQual']=train['GarageQual'].fillna(train['GarageQual'].mode()[0])
train['GarageCond']=train['GarageCond'].fillna(train['GarageCond'].mode()[0])
train['MasVnrType']=train['MasVnrType'].fillna(train['MasVnrType'].mode()[0])
train['MasVnrArea']=train['MasVnrArea'].fillna(train['MasVnrArea'].mode()[0])
train['BsmtExposure']=train['BsmtExposure'].fillna(train['BsmtExposure'].mode()[0])
train['BsmtFinType1']=train['BsmtFinType1'].fillna(train['BsmtFinType1'].mode()[0])
train['BsmtFinType2']=train['BsmtFinType2'].fillna(train['BsmtFinType2'].mode()[0])

# %% [markdown]
# We put categorical values with mode values.

# %%
train.dropna(inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   int64
#  1   MSZoning       1459 non-null   object
#  2   LotFrontage    1459 non-null   float64
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   object
#  5   LotShape       1459 non-null   object
#  6   LandContour    1459 non-null   object
#  7   Utilities      1459 non-null   object
#  8   LotConfig      1459 non-null   object
#  9   LandSlope      1459 non-null   object
#  10  Neighborhood   1459 non-null   object
#  11  Condition1     1459 non-null   object
#  12  Condition2     1459 non-null   object
#  13  BldgType       1459 non-null   object
#  14  HouseStyle     1459 non-null   object
#  15  OverallQual    1459 non-null   int64
#  16  OverallCond    1459 non-null   int64
# ...

# %%
train.shape
# Out:
# (1459, 76)

# %%
train.to_csv('newtest.csv', index=False)

# %% [markdown]
# # Perform proper feature scaling to transform feature columns and target variable (if necessary)

# %%
#Look at the datatypes
train.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 76, dtype: object

# %%
# Handle Categorical Features
columns=['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood',
         'Condition2','BldgType','Condition1','HouseStyle','SaleType',
        'SaleCondition','ExterCond',
         'ExterQual','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
        'RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','Heating','HeatingQC',
         'CentralAir',
         'Electrical','KitchenQual','Functional',
         'FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive']

# %%
len(columns)
# Out:
# 39

# %%
def category_onehot_multcols(multcolumns):
    df_final=final_df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(final_df[fields],drop_first=True)
        
        final_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([final_df,df_final],axis=1)
        
    return df_final

# %%
main_df=train.copy()

# %%
# Combining Test Data 

test_df=pd.read_csv('newtest.csv')

# %%
test_df.shape
# Out:
# (1459, 76)

# %%
test_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# 0          60       RL         65.0  ...        WD        Normal    208500
# 1          20       RL         80.0  ...        WD        Normal    181500
# 2          60       RL         68.0  ...        WD        Normal    223500
# 3          70       RL         60.0  ...        WD       Abnorml    140000
# 4          60       RL         84.0  ...        WD        Normal    250000
#
# [5 rows x 76 columns]

# %%
final_df=pd.concat([train,test_df],axis=0)

# %%
final_df['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1454    175000
# 1455    210000
# 1456    266500
# 1457    142125
# 1458    147500
# Name: SalePrice, Length: 2918, dtype: int64

# %%
final_df.shape
# Out:
# (2918, 76)

# %%
final_df=category_onehot_multcols(columns)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition2
# BldgType
# Condition1
# HouseStyle
# SaleType
# SaleCondition
# ExterCond
# ExterQual
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive

# %%
final_df.shape
# Out:
# (2918, 237)

# %%
final_df =final_df.loc[:,~final_df.columns.duplicated()]

# %%
final_df.shape
# Out:
# (2918, 177)

# %%
final_df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  ...  CarPort  Detchd  RFn  P
# 0             60         65.0     8450            7  ...        0       0    1  0
# 1             20         80.0     9600            6  ...        0       0    1  0
# 2             60         68.0    11250            7  ...        0       0    1  0
# 3             70         60.0     9550            7  ...        0       1    0  0
# 4             60         84.0    14260            8  ...        0       0    1  0
# ...          ...          ...      ...          ...  ...      ...     ...  ... ..
# 1454          60         62.0     7917            6  ...        0       0    1  0
# 1455          20         85.0    13175            6  ...        0       0    0  0
# 1456          70         66.0     9042            7  ...        0       0    1  0
# 1457          20         68.0     9717            5  ...        0       0    0  0
# ...

# %%
df_Train=final_df.iloc[:1422,:]
df_Test=final_df.iloc[1422:,:]

# %% [markdown]
# # **Feature scaling**

# %%
df_Train.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  ...  CarPort  Detchd  RFn  P
# 0          60         65.0     8450            7  ...        0       0    1  0
# 1          20         80.0     9600            6  ...        0       0    1  0
# 2          60         68.0    11250            7  ...        0       0    1  0
# 3          70         60.0     9550            7  ...        0       1    0  0
# 4          60         84.0    14260            8  ...        0       0    1  0
#
# [5 rows x 177 columns]

# %%
df_Train.shape
# Out:
# (1422, 177)

# %%
df_Test.shape
# Out:
# (1496, 177)

# %%
df_Test.drop(['SalePrice'],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X_train=df_Train.drop(['SalePrice'],axis=1)
y_train=df_Train['SalePrice']

# %%
X_train.shape
# Out:
# (1422, 176)

# %%
y_train.shape
# Out:
# (1422,)

# %%
df_Test.shape
# Out:
# (1496, 176)

# %%
df_Test.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  ...  CarPort  Detchd  RFn  P
# 1423          80    70.049958    19690            6  ...        0       0    0  0
# 1424          20    70.049958     9503            5  ...        0       1    0  0
# 1425          20    80.000000    10721            6  ...        0       1    0  0
# 1426          60    81.000000    10944            7  ...        0       0    1  0
# 1427          50    60.000000    10930            5  ...        0       0    0  0
#
# [5 rows x 176 columns]

# %% [markdown]
# # **Supervised learning models for this problem and report the output**

# %%
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %% [markdown]
# # **Support Vector Machine to predict Housing price**

# %%
SVM_classifier = svm.SVC(kernel='linear', gamma='auto', C=2)
SVM = SVM_classifier.fit(X_train,y_train)
cv = cross_val_score(SVM,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.02105263 0.         0.00704225 0.00704225 0.01760563]
# 0.010548554484803557

# %% [markdown]
# # **Decision Tree (with maximum depth restriction and no restriction)**

# %%
#Decision tree with max_depth 

from sklearn.tree import DecisionTreeClassifier
tree_clf = DecisionTreeClassifier(max_depth=2)
DTC = tree_clf.fit(X_train,y_train)
cv = cross_val_score(DTC,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [0.01403509 0.01403509 0.00352113 0.02112676 0.01408451]
# 0.013360513960958734
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)

# %%
#Decision tree with no restriction
from sklearn.tree import DecisionTreeClassifier
tree_clf1 = DecisionTreeClassifier()
DTC1 = tree_clf1.fit(X_train,y_train)
cv = cross_val_score(DTC1,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.00350877 0.01052632 0.00704225 0.00352113 0.        ]
# 0.004919693600197677

# %%
tree_clf1.predict(df_Test)
# Out:
# array([197500, 148000, 137500, ..., 164000,  91000, 139000])

# %% [markdown]
# # **Random Forest (Try with various estimators count)**

# %%
# randomforest with estimator 10  
from sklearn.ensemble import RandomForestClassifier  
classifier= RandomForestClassifier(n_estimators= 10, criterion="entropy")
RFC10= classifier.fit(X_train,y_train)  
cv = cross_val_score(RFC10,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.00701754 0.02105263 0.00704225 0.00704225 0.00352113]
# 0.00913516184828268

# %%
# randomforest with estimator  20
from sklearn.ensemble import RandomForestClassifier  
classifier5= RandomForestClassifier(n_estimators= 20, criterion="entropy")
RFC5= classifier5.fit(X_train,y_train)   
cv = cross_val_score(RFC5,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.00701754 0.00701754 0.00704225 0.01760563 0.00704225]
# 0.009145045712873733

# %%
# randomforest with estimator 30
from sklearn.ensemble import RandomForestClassifier  
classifier15= RandomForestClassifier(n_estimators= 30, criterion="entropy") 
RFC15= classifier15.fit(X_train,y_train)   
cv = cross_val_score(RFC15,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.01403509 0.01052632 0.01408451 0.01408451 0.01056338]
# 0.012658759574993822

# %% [markdown]
# # **3. Perform PCA and then apply decision tree algorithm, in your opinion does that improve the result**

# %%
#feature scalling 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_data = scaler.transform(X_train)

# %%
# Applying PCA on linear regression and decision tree 

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
x_pca = pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (1422, 176)

# %%
x_pca.shape
# Out:
# (1422, 2)

# %%
df_Test.shape
# Out:
# (1496, 176)

# %%
df_Test.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  ...  CarPort  Detchd  RFn  P
# 1423          80    70.049958    19690            6  ...        0       0    0  0
# 1424          20    70.049958     9503            5  ...        0       1    0  0
# 1425          20    80.000000    10721            6  ...        0       1    0  0
# 1426          60    81.000000    10944            7  ...        0       0    1  0
# 1427          50    60.000000    10930            5  ...        0       0    0  0
#
# [5 rows x 176 columns]

# %%
SVM_classifier = svm.SVC(kernel='linear', gamma='auto', C=2)
SVM = SVM_classifier.fit(X_train,y_train)
cv = cross_val_score(SVM,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.02105263 0.         0.00704225 0.00704225 0.01760563]
# 0.010548554484803557

# %%
from sklearn.ensemble import RandomForestClassifier
RM_pca = RandomForestClassifier(max_depth=2)
RMC = RM_pca.fit(x_pca,y_train)
cv = cross_val_score(RMC,x_pca,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.0245614  0.01754386 0.02464789 0.01408451 0.01760563]
# 0.019688658265381763

# %% [markdown]
# The performance is better after applying PCA.

# %% [markdown]
# # **Create Submission**

# %%
import pickle
filename= 'final_model.pkl'
pickle.dump(RMC, open(filename,'wb'))

# %%
y_pred= RMC.predict(x_pca)

# %%
print(y_pred)
# Out:
# [190000 190000 190000 ... 190000 135000 140000]

# %%
#Create Sample Submission file and Submit using ANN
pred=pd.DataFrame(y_pred)
sub_df=pd.read_csv('sample_submission.csv')
datasets=pd.concat([sub_df['Id'],pred],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('final_submission.csv',index=False)
